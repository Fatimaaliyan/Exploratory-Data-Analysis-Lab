# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Data Visualization Lab**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# In this assignment you will be focusing on the visualization of data.
#
# The data set will be presented to you in the form of a RDBMS.
#
# You will have to use SQL queries to extract the data.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Visualize the distribution of data.
#
# -   Visualize the relationship between two features.
#
# -   Visualize composition of data.
#
# -   Visualize comparison of data.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Demo: How to work with database

# %% [markdown]
# Download database file.

# %%
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m4_survey_data.sqlite
# Out:
# --2023-11-22 10:52:39--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m4_survey_data.sqlite
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104, 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36679680 (35M) [application/octet-stream]
# Saving to: ‘m4_survey_data.sqlite’
#
# m4_survey_data.sqli 100%[===================>]  34.98M  23.6MB/s    in 1.5s
#
# 2023-11-22 10:52:42 (23.6 MB/s) - ‘m4_survey_data.sqlite’ saved [36679680/36679680]

# %% [markdown]
# Connect to the database.

# %%
import sqlite3
conn = sqlite3.connect("m4_survey_data.sqlite") # open a database connection

# %% [markdown]
# Import pandas module.

# %%
import pandas as pd

# %% [markdown]
# ## Demo: How to run an sql query

# %%
# print how many rows are there in the table named 'master'
QUERY = """
SELECT COUNT(*)
FROM master
"""

# the read_sql_query runs the sql query and returns the data as a dataframe
df = pd.read_sql_query(QUERY,conn)
df.head()
# Out:
#    COUNT(*)
# 0     11398

# %% [markdown]
# ## Demo: How to list all tables

# %%
# print all the tables names in the database
QUERY = """
SELECT name as Table_Name FROM
sqlite_master WHERE
type = 'table'
"""
# the read_sql_query runs the sql query and returns the data as a dataframe
pd.read_sql_query(QUERY,conn)
# Out:
#                 Table_Name
# 0                 EduOther
# 1                  DevType
# 2                  LastInt
# 3               JobFactors
# 4                 WorkPlan
# 5            WorkChallenge
# 6       LanguageWorkedWith
# 7   LanguageDesireNextYear
# 8       DatabaseWorkedWith
# 9   DatabaseDesireNextYear
# 10      PlatformWorkedWith
# 11  PlatformDesireNextYear
# 12      WebFrameWorkedWith
# 13  WebFrameDesireNextYear
# 14      MiscTechWorkedWith
# 15  MiscTechDesireNextYear
# 16              DevEnviron
# 17              Containers
# 18               SOVisitTo
# 19            SONewContent
# 20                  Gender
# 21               Sexuality
# 22               Ethnicity
# 23                  master

# %% [markdown]
# ## Demo: How to run a group by query

# %%
QUERY = """
SELECT Age,COUNT(*) as count
FROM master
group by age
order by age
"""
pd.read_sql_query(QUERY,conn)
# Out:
#      Age  count
# 0    NaN    287
# 1   16.0      3
# 2   17.0      6
# 3   18.0     29
# 4   19.0     78
# 5   20.0    109
# 6   21.0    203
# 7   22.0    406
# 8   23.0    581
# 9   24.0    679
# 10  25.0    738
# 11  26.0    720
# 12  27.0    724
# 13  28.0    787
# 14  29.0    697
# 15  30.0    651
# 16  31.0    531
# 17  32.0    489
# 18  33.0    483
# 19  34.0    395
# 20  35.0    393
# 21  36.0    308
# 22  37.0    280
# 23  38.0    279
# 24  39.0    232
# 25  40.0    187
# 26  41.0    136
# 27  42.0    162
# 28  43.0    100
# 29  44.0     95
# 30  45.0     85
# 31  46.0     66
# 32  47.0     68
# 33  48.0     64
# 34  49.0     66
# 35  50.0     57
# 36  51.0     29
# 37  52.0     41
# 38  53.0     32
# 39  54.0     26
# 40  55.0     13
# 41  56.0     16
# 42  57.0     11
# 43  58.0     12
# 44  59.0     11
# 45  60.0      2
# 46  61.0     10
# 47  62.0      5
# 48  63.0      7
# 49  65.0      2
# 50  66.0      1
# 51  67.0      1
# 52  69.0      1
# 53  71.0      2
# ...

# %% [markdown]
# ## Demo: How to describe a table

# %%
table_name = 'master'  # the table you wish to describe

QUERY = """
SELECT sql FROM sqlite_master
WHERE name= '{}'
""".format(table_name)

df = pd.read_sql_query(QUERY,conn)
print(df.iat[0,0])
# Out:
# CREATE TABLE "master" (
# "index" INTEGER,
#   "Respondent" INTEGER,
#   "MainBranch" TEXT,
#   "Hobbyist" TEXT,
#   "OpenSourcer" TEXT,
#   "OpenSource" TEXT,
#   "Employment" TEXT,
#   "Country" TEXT,
#   "Student" TEXT,
#   "EdLevel" TEXT,
#   "UndergradMajor" TEXT,
#   "OrgSize" TEXT,
#   "YearsCode" TEXT,
#   "Age1stCode" TEXT,
#   "YearsCodePro" TEXT,
#   "CareerSat" TEXT,
#   "JobSat" TEXT,
#   "MgrIdiot" TEXT,
#   "MgrMoney" TEXT,
#   "MgrWant" TEXT,
#   "JobSeek" TEXT,
#   "LastHireDate" TEXT,
#   "FizzBuzz" TEXT,
#   "ResumeUpdate" TEXT,
#   "CurrencySymbol" TEXT,
#   "CurrencyDesc" TEXT,
#   "CompTotal" REAL,
#   "CompFreq" TEXT,
#   "ConvertedComp" REAL,
#   "WorkWeekHrs" REAL,
#   "WorkRemote" TEXT,
#   "WorkLoc" TEXT,
#   "ImpSyn" TEXT,
#   "CodeRev" TEXT,
#   "CodeRevHrs" REAL,
#   "UnitTests" TEXT,
#   "PurchaseHow" TEXT,
#   "PurchaseWhat" TEXT,
#   "OpSys" TEXT,
#   "BlockchainOrg" TEXT,
#   "BlockchainIs" TEXT,
#   "BetterLife" TEXT,
#   "ITperson" TEXT,
# ...

# %% [markdown]
# # Hands-on Lab

# %% [markdown]
# ## Visualizing distribution of data

# %% [markdown]
# ### Histograms

# %% [markdown]
# Plot a histogram of `ConvertedComp.`

# %%
import matplotlib.pyplot as plt
import pandas as pd
import sqlite3

# Connect to the database
conn = sqlite3.connect("m4_survey_data.sqlite")

# Query to select the 'ConvertedComp' column
QUERY = """
SELECT ConvertedComp
FROM master
"""

# Read the data into a DataFrame
df = pd.read_sql_query(QUERY, conn)

# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(df['ConvertedComp'], bins=30, color='skyblue', edgecolor='black')
plt.title('Histogram of Converted Compensation')
plt.xlabel('Converted Compensation (USD)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Box Plots

# %% [markdown]
# Plot a box plot of `Age.`

# %%
# Query to select the 'Age' column
QUERY = """
SELECT Age
FROM master
"""

# Read the data into a DataFrame
df = pd.read_sql_query(QUERY, conn)

# Check the first few rows of the DataFrame
print(df.head())

# Check the summary statistics of the 'Age' column
print(df['Age'].describe())

# Plot box plot
plt.figure(figsize=(8, 6))
plt.boxplot(df['Age'], vert=False)
plt.title('Box Plot of Age')
plt.xlabel('Age')
plt.show()
# Out:
#     Age
# 0  22.0
# 1  23.0
# 2  28.0
# 3  26.0
# 4  29.0
# count    11111.000000
# mean        30.779318
# std          7.393680
# min         16.000000
# 25%         25.000000
# 50%         29.000000
# 75%         35.000000
# max         99.000000
# Name: Age, dtype: float64

# %% [markdown]
# ## Visualizing relationships in data

# %% [markdown]
# ### Scatter Plots

# %% [markdown]
# Create a scatter plot of `Age` and `WorkWeekHrs.`

# %%
QUERY = """
SELECT Age, WorkWeekHrs
FROM master
"""

# Read the data into a DataFrame
df = pd.read_sql_query(QUERY, conn)

# Check for null values and drop them if necessary
df = df.dropna()

# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df['Age'], df['WorkWeekHrs'], alpha=0.5)
plt.title('Scatter Plot of Age vs WorkWeekHrs')
plt.xlabel('Age')
plt.ylabel('WorkWeekHrs')
plt.show()

# %% [markdown]
# ### Bubble Plots

# %% [markdown]
# Create a bubble plot of `WorkWeekHrs` and `CodeRevHrs`, use `Age` column as bubble size.

# %%
# Query to select 'Age', 'WorkWeekHrs', and 'CodeRevHrs' columns
QUERY = """
SELECT Age, WorkWeekHrs, CodeRevHrs
FROM master
"""

# Read the data into a DataFrame
df = pd.read_sql_query(QUERY, conn)

# Check for null values and drop them if necessary
df = df.dropna()

# Create a bubble plot
plt.figure(figsize=(12, 8))
plt.scatter(df['WorkWeekHrs'], df['CodeRevHrs'], s=df['Age'], alpha=0.5)
plt.title('Bubble Plot of WorkWeekHrs vs CodeRevHrs')
plt.xlabel('WorkWeekHrs')
plt.ylabel('CodeRevHrs')
plt.colorbar(label='Age (Bubble Size)')
plt.show()

# %% [markdown]
# ## Visualizing composition of data

# %% [markdown]
# ### Pie Charts

# %% [markdown]
# Create a pie chart of the top 5 databases that respondents wish to learn next year. Label the pie chart with database names. Display percentages of each database on the pie chart.

# %%
# Query to select the top 5 databases respondents wish to learn next year
QUERY = """
SELECT DatabaseDesireNextYear, COUNT(*) as count
FROM DatabaseDesireNextYear
GROUP BY DatabaseDesireNextYear
ORDER BY count DESC
LIMIT 5
"""

# Read the data into a DataFrame
df = pd.read_sql_query(QUERY, conn)

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(df['count'], labels=df['DatabaseDesireNextYear'], autopct='%1.1f%%', startangle=140)
plt.title('Top 5 Databases Respondents Wish to Learn Next Year')
plt.show()

# %% [markdown]
# ### Stacked Charts

# %% [markdown]
# Create a stacked chart of median `WorkWeekHrs` and `CodeRevHrs` for the age group 30 to 35.

# %%
# Query to select median WorkWeekHrs and CodeRevHrs for the age group 30 to 35
QUERY = """
SELECT Age, 
       AVG(WorkWeekHrs) as MedianWorkWeekHrs, 
       AVG(CodeRevHrs) as MedianCodeRevHrs
FROM master
WHERE Age BETWEEN 30 AND 35
GROUP BY Age
ORDER BY Age
"""

# Read the data into a DataFrame
df = pd.read_sql_query(QUERY, conn)

# Create a stacked chart
plt.figure(figsize=(10, 6))
plt.bar(df['Age'], df['MedianWorkWeekHrs'], label='Median WorkWeekHrs')
plt.bar(df['Age'], df['MedianCodeRevHrs'], bottom=df['MedianWorkWeekHrs'], label='Median CodeRevHrs')
plt.xlabel('Age')
plt.ylabel('Median Hours')
plt.title('Stacked Chart of Median WorkWeekHrs and CodeRevHrs (Age 30-35)')
plt.legend()
plt.show()

# %% [markdown]
# ## Visualizing comparison of data

# %% [markdown]
# ### Line Chart

# %% [markdown]
# Plot the median `ConvertedComp` for all ages from 45 to 60.

# %%
QUERY = """
SELECT Age, 
       AVG(ConvertedComp) as MedianConvertedComp
FROM master
WHERE Age BETWEEN 45 AND 60
GROUP BY Age
ORDER BY Age
"""

# Read the data into a DataFrame
df = pd.read_sql_query(QUERY, conn)

# Plot the line chart
plt.figure(figsize=(10, 6))
plt.plot(df['Age'], df['MedianConvertedComp'], marker='o', color='blue', label='Median ConvertedComp')
plt.xlabel('Age')
plt.ylabel('Median ConvertedComp')
plt.title('Line Chart of Median ConvertedComp (Ages 45-60)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Bar Chart

# %% [markdown]
# Create a horizontal bar chart using column `MainBranch.`

# %%
# Query to select the count of respondents for each MainBranch category
QUERY = """
SELECT MainBranch, COUNT(*) as RespondentCount
FROM master
GROUP BY MainBranch
"""

# Read the data into a DataFrame
df_main_branch = pd.read_sql_query(QUERY, conn)

# Plot the horizontal bar chart
plt.figure(figsize=(10, 6))
plt.barh(df_main_branch['MainBranch'], df_main_branch['RespondentCount'], color='skyblue')
plt.xlabel('Number of Respondents')
plt.ylabel('MainBranch')
plt.title('Horizontal Bar Chart of Respondents by MainBranch')
plt.grid(axis='x')
plt.show()

# %% [markdown]
# How many respondents indicated that they currently work with 'SQL'?

# %%
# Write the SQL query
query = """
SELECT COUNT(*) as SQLRespondents
FROM LanguageWorkedWith
WHERE LanguageWorkedWith LIKE '%SQL%';
"""

# Execute the query and read the result into a DataFrame
result_df = pd.read_sql_query(query, conn)

# Display the result
print("Number of respondents who work with 'SQL':", result_df['SQLRespondents'].values[0])
# Out:
# Number of respondents who work with 'SQL': 7106

# %%
# !pip install ipython-sql
# Install ipython-sql if you haven't already
# !pip install ipython-sql

# Load the SQL extension
# %load_ext sql

# Connect to the SQLite database
# %sql sqlite:///m4_survey_data.sqlite
# Out:
# ...
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# 'Connected: @m4_survey_data.sqlite'

# %%
# Run the SQL query to get the rank of Python in the list of most popular languages respondents wish to learn next year
# %sql SELECT LanguageDesireNextYear, ROW_NUMBER() OVER (ORDER BY COUNT(*) DESC) as Rank \
      FROM LanguageDesireNextYear \
      GROUP BY LanguageDesireNextYear \
      ORDER BY Rank;
# Out:
#  * sqlite:///m4_survey_data.sqlite
# Done.
# [('JavaScript', 1),
#  ('HTML/CSS', 2),
#  ('Python', 3),
#  ('SQL', 4),
#  ('TypeScript', 5),
#  ('C#', 6),
#  ('Bash/Shell/PowerShell', 7),
#  ('Java', 8),
#  ('Go', 9),
#  ('Kotlin', 10),
#  ('C++', 11),
#  ('Rust', 12),
#  ('PHP', 13),
#  ('WebAssembly', 14),
#  ('Swift', 15),
#  ('Ruby', 16),
#  ('C', 17),
#  ('Scala', 18),
#  ('R', 19),
#  ('Other(s):', 20),
#  ('F#', 21),
#  ('Elixir', 22),
#  ('Dart', 23),
#  ('Clojure', 24),
#  ('Assembly', 25),
#  ('Objective-C', 26),
#  ('Erlang', 27),
#  ('VBA', 28)]

# %% [markdown]
# How many respondents indicated that they work on 'MySQL' only?

# %%
import pandas as pd
import sqlite3

# Connect to the database
conn = sqlite3.connect("m4_survey_data.sqlite")

# Write and execute the SQL query
query = """
SELECT COUNT(*) as MySQLRespondents
FROM LanguageWorkedWith
WHERE LanguageWorkedWith = 'MySQL';
"""

result = pd.read_sql_query(query, conn)

# Display the result
print(result)
# Out:
#    MySQLRespondents
# 0                 0

# %% [markdown]
# Based on the Line Chart of Age and median ConvertedComp for the age group 25-30,
# what kind of correlation do you see between Age and median ConvertedComp?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3

# Connect to the database
conn = sqlite3.connect("m4_survey_data.sqlite")

df = pd.read_sql_query("SELECT * FROM master", conn)

# Filter the data for the age group 25-30
df_age_25_30 = df[(df['Age'] >= 25) & (df['Age'] <= 30)]

# Create a line plot
plt.figure(figsize=(10, 6))
sns.lineplot(x='Age', y='ConvertedComp', data=df_age_25_30)

# Set plot labels and title
plt.xlabel('Age')
plt.ylabel('Median Converted Compensation')
plt.title('Line Chart of Age vs. Median Converted Compensation (Age Group: 25-30)')

# Show the plot
plt.show()

# %% [markdown]
# Close the database connection.

# %%
conn.close()

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
